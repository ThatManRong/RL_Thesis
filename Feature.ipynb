# %% [markdown]
# <a href="https://colab.research.google.com/github/ThatManRong/RL_Thesis/blob/main/Feature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Input, Dense, Conv1D, MaxPooling1D, UpSampling1D, BatchNormalization, LSTM, RepeatVector
from keras.models import Model
from keras.models import model_from_json
from keras import regularizers
import datetime
import time
import requests as req
import json
import pandas as pd
import pickle
import os
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
startdate="01/01/2015"
window_length = 50
encoding_dim = 15
epochs = 100
test_samples = 2000

# %%
def mkdate(ts):
    return datetime.datetime.fromtimestamp(
        int(ts)
    ).strftime('%Y-%m-%d')

def plot_examples(stock_input, stock_decoded):
    n = 10  
    plt.figure(figsize=(20, 4))
    for i, idx in enumerate(list(np.arange(0, test_samples, 200))):
        # display original
        ax = plt.subplot(2, n, i + 1)
        if i == 0:
            ax.set_ylabel("Input", fontweight=600)
        else:
            ax.get_yaxis().set_visible(False)
        plt.plot(stock_input[idx])
        ax.get_xaxis().set_visible(False)
        

        # display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        if i == 0:
            ax.set_ylabel("Output", fontweight=600)
        else:
            ax.get_yaxis().set_visible(False)
        plt.plot(stock_decoded[idx])
        ax.get_xaxis().set_visible(False)
        
        
def plot_history(history):
    plt.figure(figsize=(15, 5))
    ax = plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"])
    plt.title("Train loss")
    ax = plt.subplot(1, 2, 2)
    plt.plot(history.history["val_loss"])
    plt.title("Test loss")

# %%
start_timestamp = time.mktime(datetime.datetime.strptime(startdate, "%d/%m/%Y").timetuple())
end_timestamp = int(time.time())
one_week = 3600*24*7 # s
one_day = 3600*24 # s
weeks = list(np.arange(start_timestamp, end_timestamp, one_week))
days_recorded = (datetime.datetime.fromtimestamp(end_timestamp)-datetime.datetime.fromtimestamp(start_timestamp)).days
print("days_recorded ",days_recorded)
data = []
if not os.path.isfile("data.pickle"):
    s = req.Session()
    r = s.get("https://www.coindesk.com/price/")
    for i in range(1, len(weeks)):
        start_weekday = mkdate(weeks[i-1])
        end_weekday = mkdate(weeks[i]-one_day)
        print(start_weekday, end_weekday)
        r = s.get("https://api.coindesk.com/charts/data?data=close&startdate={}&enddate={}&exchanges=bpi&dev=1&index=USD".format(start_weekday, end_weekday))
        ans = json.loads(r.text.replace("cb(", "").replace(");",""))["bpi"]
        ans.sort(key=lambda x: x[0])
        for pricepoint in ans:
            if pricepoint[0]/1000 >= weeks[i-1] and pricepoint[0]/1000 < (weeks[i]-one_day):
                data.append([int(pricepoint[0]/1000), pricepoint[1]])
                
    pickle.dump(data, open("./data.pickle", "wb"))
else:
    data = pickle.load(open("./data.pickle", "rb"))

df = pd.DataFrame(np.array(data)[:,1], columns=['price'])
df['pct_change'] = df.price.pct_change()
df['log_ret'] = np.log(df.price) - np.log(df.price.shift(1)) #Get log returns

scaler = MinMaxScaler()
x_train_nonscaled = np.array([df['log_ret'].values[i-window_length:i].reshape(-1, 1) for i in tqdm(range(window_length+1,len(df['log_ret'])))])
x_train = np.array([scaler.fit_transform(df['log_ret'].values[i-window_length:i].reshape(-1, 1)) for i in tqdm(range(window_length+1,len(df['log_ret'])))])

x_test = x_train[-test_samples:]
x_train = x_train[:-test_samples]

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# Out:
# days_recorded  2178
# 100%|██████████| 41746/41746 [00:00<00:00, 233664.31it/s]
# 100%|██████████| 41746/41746 [00:06<00:00, 6201.93it/s]

# %%
plt.figure(figsize=(20,10))
plt.plot(np.array(data)[:,1])

# %%
print("Percentage of test data: {}%".format((test_samples/len(x_train))*100))
# Out:
# Percentage of test data: 5.031952900920848%

# %% [markdown]
# #Simple MLP

# %%
x_train_simple = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_simple = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# this is our input placeholder
input_window = Input(shape=(window_length,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_window)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(window_length, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_window, decoded)

# this model maps an input to its encoded representation
encoder = Model(input_window, encoded)


autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train_simple, x_train_simple,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test_simple, x_test_simple))

decoded_stocks = autoencoder.predict(x_test_simple)
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 15)                765
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                800
# =================================================================
# Total params: 1,565
# Trainable params: 1,565
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 39/39 [==============================] - 1s 8ms/step - loss: 0.6967 - val_loss: 0.6920
# Epoch 2/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6911 - val_loss: 0.6882
# Epoch 3/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6863 - val_loss: 0.6819
# Epoch 4/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6788 - val_loss: 0.6745
# Epoch 5/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6708 - val_loss: 0.6668
# Epoch 6/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6618 - val_loss: 0.6591
# Epoch 7/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6539 - val_loss: 0.6519
# Epoch 8/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6465 - val_loss: 0.6462
# Epoch 9/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6404 - val_loss: 0.6423
# Epoch 10/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6370 - val_loss: 0.6397
# Epoch 11/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6344 - val_loss: 0.6379
# Epoch 12/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6322 - val_loss: 0.6367
# Epoch 13/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6316 - val_loss: 0.6357
# Epoch 14/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6301 - val_loss: 0.6350
# Epoch 15/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6298 - val_loss: 0.6344
# Epoch 16/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6291 - val_loss: 0.6336
# Epoch 17/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6277 - val_loss: 0.6327
# Epoch 18/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6271 - val_loss: 0.6321
# Epoch 19/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6268 - val_loss: 0.6318
# Epoch 20/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6266 - val_loss: 0.6315
# Epoch 21/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6264 - val_loss: 0.6313
# Epoch 22/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6262 - val_loss: 0.6312
# Epoch 23/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6260 - val_loss: 0.6311
# Epoch 24/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6255 - val_loss: 0.6311
# Epoch 25/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6250 - val_loss: 0.6310
# Epoch 26/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6263 - val_loss: 0.6309
# Epoch 27/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6256 - val_loss: 0.6309
# Epoch 28/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6253 - val_loss: 0.6309
# Epoch 29/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6254 - val_loss: 0.6308
# Epoch 30/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6252 - val_loss: 0.6308
# Epoch 31/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6258 - val_loss: 0.6308
# Epoch 32/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6255 - val_loss: 0.6308
# Epoch 33/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6251 - val_loss: 0.6308
# Epoch 34/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6252 - val_loss: 0.6308
# Epoch 35/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6254 - val_loss: 0.6307
# Epoch 36/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6257 - val_loss: 0.6307
# Epoch 37/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6258 - val_loss: 0.6307
# Epoch 38/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6258 - val_loss: 0.6307
# Epoch 39/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6257 - val_loss: 0.6307
# Epoch 40/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6258 - val_loss: 0.6307
# Epoch 41/100
# 39/39 [==============================] - 0s 9ms/step - loss: 0.6253 - val_loss: 0.6307
# Epoch 42/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6255 - val_loss: 0.6307
# Epoch 43/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6253 - val_loss: 0.6307
# Epoch 44/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6249 - val_loss: 0.6307
# Epoch 45/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6252 - val_loss: 0.6307
# Epoch 46/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6254 - val_loss: 0.6306
# Epoch 47/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6255 - val_loss: 0.6306
# Epoch 48/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6251 - val_loss: 0.6306
# Epoch 49/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6253 - val_loss: 0.6306
# Epoch 50/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6255 - val_loss: 0.6306
# Epoch 51/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6254 - val_loss: 0.6306
# Epoch 52/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6253 - val_loss: 0.6306
# Epoch 53/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6248 - val_loss: 0.6306
# Epoch 54/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6252 - val_loss: 0.6306
# Epoch 55/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6254 - val_loss: 0.6305
# Epoch 56/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6250 - val_loss: 0.6305
# Epoch 57/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6254 - val_loss: 0.6305
# Epoch 58/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6251 - val_loss: 0.6305
# Epoch 59/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6248 - val_loss: 0.6305
# Epoch 60/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6254 - val_loss: 0.6305
# Epoch 61/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6252 - val_loss: 0.6305
# Epoch 62/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6245 - val_loss: 0.6305
# Epoch 63/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6258 - val_loss: 0.6304
# Epoch 64/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6253 - val_loss: 0.6305
# Epoch 65/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6255 - val_loss: 0.6304
# Epoch 66/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6247 - val_loss: 0.6304
# Epoch 67/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6250 - val_loss: 0.6304
# Epoch 68/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6251 - val_loss: 0.6304
# Epoch 69/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6252 - val_loss: 0.6303
# Epoch 70/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6244 - val_loss: 0.6303
# Epoch 71/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6247 - val_loss: 0.6303
# Epoch 72/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6246 - val_loss: 0.6303
# Epoch 73/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6249 - val_loss: 0.6303
# Epoch 74/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6247 - val_loss: 0.6303
# Epoch 75/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6246 - val_loss: 0.6302
# Epoch 76/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6247 - val_loss: 0.6302
# Epoch 77/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6248 - val_loss: 0.6302
# Epoch 78/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6250 - val_loss: 0.6302
# Epoch 79/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6253 - val_loss: 0.6301
# Epoch 80/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6242 - val_loss: 0.6301
# Epoch 81/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6247 - val_loss: 0.6301
# Epoch 82/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6244 - val_loss: 0.6301
# Epoch 83/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6246 - val_loss: 0.6300
# Epoch 84/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6244 - val_loss: 0.6300
# Epoch 85/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6239 - val_loss: 0.6300
# Epoch 86/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6244 - val_loss: 0.6299
# Epoch 87/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6246 - val_loss: 0.6299
# Epoch 88/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6244 - val_loss: 0.6299
# Epoch 89/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6244 - val_loss: 0.6299
# Epoch 90/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6245 - val_loss: 0.6298
# Epoch 91/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6235 - val_loss: 0.6298
# Epoch 92/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6243 - val_loss: 0.6297
# Epoch 93/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6245 - val_loss: 0.6298
# Epoch 94/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6239 - val_loss: 0.6297
# Epoch 95/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6240 - val_loss: 0.6297
# Epoch 96/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6236 - val_loss: 0.6296
# Epoch 97/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6244 - val_loss: 0.6296
# Epoch 98/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6242 - val_loss: 0.6296
# Epoch 99/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6243 - val_loss: 0.6296
# Epoch 100/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6238 - val_loss: 0.6295

# %%
plot_history(history)
plot_examples(x_test_simple, decoded_stocks)

# %% [markdown]
# #Deep Autoencoder
#
# Fast Convergence, result looks okay

# %%
x_train_deep = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_deep = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

input_window = Input(shape=(window_length,))

x = Dense(6, activation='relu')(input_window)
x = BatchNormalization()(x)
encoded = Dense(encoding_dim, activation='relu')(x)
# "decoded" is the lossy reconstruction of the input

x = Dense(6, activation='relu')(encoded)
x = BatchNormalization()(x)
decoded = Dense(window_length, activation='sigmoid')(x)

# this model maps an input to its reconstruction
autoencoder = Model(input_window, decoded)

# this model maps an input to its encoded representation
encoder = Model(input_window, encoded)

autoencoder.summary()

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train_deep, x_train_deep,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test_deep, x_test_deep))

decoded_stocks = autoencoder.predict(x_test_deep)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 10)]              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 66
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6)                 24
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 21
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 24
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 6)                 24
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                70
# =================================================================
# Total params: 229
# Trainable params: 205
# Non-trainable params: 24
# _________________________________________________________________
# Epoch 1/100
# 39/39 [==============================] - 1s 7ms/step - loss: 0.7174 - val_loss: 0.6912
# Epoch 2/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6918 - val_loss: 0.6885
# Epoch 3/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6739 - val_loss: 0.6844
# Epoch 4/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6616 - val_loss: 0.6783
# Epoch 5/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6529 - val_loss: 0.6711
# Epoch 6/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6468 - val_loss: 0.6638
# Epoch 7/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6419 - val_loss: 0.6569
# Epoch 8/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.
100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6111 - val_loss: 0.6096
# Epoch 77/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6109 - val_loss: 0.6097
# Epoch 78/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6109 - val_loss: 0.6096
# Epoch 79/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6113 - val_loss: 0.6097
# Epoch 80/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6117 - val_loss: 0.6096
# Epoch 81/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6114 - val_loss: 0.6097
# Epoch 82/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6112 - val_loss: 0.6096
# Epoch 83/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6111 - val_loss: 0.6097
# Epoch 84/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6109 - val_loss: 0.6097
# Epoch 85/100
# 39/39 [==============================] - 0s 8ms/step - loss: 0.6109 - val_loss: 0.6097
# Epoch 86/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6110 - val_loss: 0.6096
# Epoch 87/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6109 - val_loss: 0.6096
# Epoch 88/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6112 - val_loss: 0.6096
# Epoch 89/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6109 - val_loss: 0.6096
# Epoch 90/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6111 - val_loss: 0.6096
# Epoch 91/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6112 - val_loss: 0.6096
# Epoch 92/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6112 - val_loss: 0.6096
# Epoch 93/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6112 - val_loss: 0.6096
# Epoch 94/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6113 - val_loss: 0.6095
# Epoch 95/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6115 - val_loss: 0.6096
# Epoch 96/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6112 - val_loss: 0.6096
# Epoch 97/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6111 - val_loss: 0.6095
# Epoch 98/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6111 - val_loss: 0.6095
# Epoch 99/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6111 - val_loss: 0.6095
# Epoch 100/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6110 - val_loss: 0.6096

# %%
plot_history(history)
plot_examples(x_test_deep, decoded_stocks)

# %% [markdown]
# #CNN Autoencoder
#
# Slow convergence, and bad result in general.

# %%
input_window = Input(shape=(window_length,1))
x = Conv1D(16, 3, activation="relu", padding="same")(input_window) # 10 dims
#x = BatchNormalization()(x)
x = MaxPooling1D(2, padding="same")(x) # 5 dims
x = Conv1D(1, 3, activation="relu", padding="same")(x) # 5 dims
#x = BatchNormalization()(x)
encoded = MaxPooling1D(2, padding="same")(x) # 3 dims

encoder = Model(input_window, encoded)

# 3 dimensions in the encoded layer

x = Conv1D(1, 3, activation="relu", padding="same")(encoded) # 3 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 6 dims
x = Conv1D(16, 2, activation='relu')(x) # 5 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 10 dims
decoded = Conv1D(1, 3, activation='sigmoid', padding='same')(x) # 10 dims
autoencoder = Model(input_window, decoded)
autoencoder.summary()

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train, x_train,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test))

decoded_stocks = autoencoder.predict(x_test)
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 10, 1)]           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 10, 16)            64
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 5, 16)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 5, 1)              49
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 3, 1)              0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 3, 1)              4
# _________________________________________________________________
# up_sampling1d (UpSampling1D) (None, 6, 1)              0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 5, 16)             48
# _________________________________________________________________
# up_sampling1d_1 (UpSampling1 (None, 10, 16)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 10, 1)             49
# =================================================================
# Total params: 214
# Trainable params: 214
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 39/39 [==============================] - 2s 23ms/step - loss: 0.6950 - val_loss: 0.6930
# Epoch 2/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.6913 - val_loss: 0.6863
# Epoch 3/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6816 - val_loss: 0.6682
# Epoch 4/100
# 39/39 [==============================] - 1s 20ms/step - loss: 0.6658 - val_loss: 0.6588
# Epoch 5/100
# 39/39 [==============================] - 2s 41ms/step - loss: 0.6596 - val_loss: 0.6547
# Epoch 6/100
# 39/39 [==============================] - 1s 33ms/step - loss: 0.6569 - val_loss: 0.6521
# Epoch 7/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6552 - val_loss: 0.6503
# Epoch 8/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6537 - val_loss: 0.6487
# Epoch 9/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6516 - val_loss: 0.6469
# Epoch 10/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6505 - val_loss: 0.6450
# Epoch 11/100
# 39/39 [==============================] - 1s 33ms/step - loss: 0.6483 - val_loss: 0.6433
# Epoch 12/100
# 39/39 [==============================] - 1s 32ms/step - loss: 0.6472 - val_loss: 0.6420
# Epoch 13/100
# 39/39 [==============================] - 1s 25ms/step - loss: 0.6459 - val_loss: 0.6408
# Epoch 14/100
# 39/39 [==============================] - 1s 17ms/step - loss: 0.
100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6193 - val_loss: 0.6152
# Epoch 81/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6196 - val_loss: 0.6150
# Epoch 82/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6190 - val_loss: 0.6148
# Epoch 83/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6186 - val_loss: 0.6146
# Epoch 84/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6186 - val_loss: 0.6145
# Epoch 85/100
# 39/39 [==============================] - 1s 19ms/step - loss: 0.6182 - val_loss: 0.6144
# Epoch 86/100
# 39/39 [==============================] - 1s 19ms/step - loss: 0.6186 - val_loss: 0.6143
# Epoch 87/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6179 - val_loss: 0.6142
# Epoch 88/100
# 39/39 [==============================] - 1s 19ms/step - loss: 0.6186 - val_loss: 0.6141
# Epoch 89/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6177 - val_loss: 0.6141
# Epoch 90/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6180 - val_loss: 0.6141
# Epoch 91/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6179 - val_loss: 0.6140
# Epoch 92/100
# 39/39 [==============================] - 1s 19ms/step - loss: 0.6183 - val_loss: 0.6140
# Epoch 93/100
# 39/39 [==============================] - 1s 19ms/step - loss: 0.6181 - val_loss: 0.6139
# Epoch 94/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6179 - val_loss: 0.6139
# Epoch 95/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6177 - val_loss: 0.6138
# Epoch 96/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6185 - val_loss: 0.6138
# Epoch 97/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6176 - val_loss: 0.6138
# Epoch 98/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6177 - val_loss: 0.6138
# Epoch 99/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6179 - val_loss: 0.6137
# Epoch 100/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6176 - val_loss: 0.6137

# %%
plot_history(history)
plot_examples(x_test_deep, decoded_stocks)

# %% [markdown]
# #LSTM Autoencoder
#
# Maybe better dealing with sequential data?
#
# After testings: No, because of "lossy" compression.
# https://www.deeplearningbook.org/contents/rnn.html

# %%
inputs = Input(shape=(window_length, 1))
encoded = LSTM(encoding_dim)(inputs)

decoded = RepeatVector(window_length)(encoded)
decoded = LSTM(1, return_sequences=True)(decoded)

sequence_autoencoder = Model(inputs, decoded)
encoder = Model(inputs, encoded)
sequence_autoencoder.summary()

sequence_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = sequence_autoencoder.fit(x_train, x_train,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test))

decoded_stocks = sequence_autoencoder.predict(x_test)
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 10, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 3)                 60
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 10, 3)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 1)             20
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 39/39 [==============================] - 5s 34ms/step - loss: 0.8785 - val_loss: 0.7707
# Epoch 2/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.7694 - val_loss: 0.7362
# Epoch 3/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.7380 - val_loss: 0.7218
# Epoch 4/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.7237 - val_loss: 0.7148
# Epoch 5/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.7158 - val_loss: 0.7109
# Epoch 6/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.7113 - val_loss: 0.7079
# Epoch 7/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.7085 - val_loss: 0.7053
# Epoch 8/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.7055 - val_loss: 0.7030
# Epoch 9/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.7031 - val_loss: 0.7009
# Epoch 10/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.7011 - val_loss: 0.6991
# Epoch 11/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6996 - val_loss: 0.6974
# Epoch 12/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6979 - val_loss: 0.6956
# Epoch 13/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6961 - val_loss: 0.6938
# Epoch 14/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6943 - val_loss: 0.6917
# Epoch 15/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6925 - val_loss: 0.6892
# Epoch 16/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6901 - val_loss: 0.6861
# Epoch 17/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6869 - val_loss: 0.6821
# Epoch 18/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6837 - val_loss: 0.6766
# Epoch 19/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6783 - val_loss: 0.6704
# Epoch 20/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6734 - val_loss: 0.6676
# Epoch 21/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6717 - val_loss: 0.6669
# Epoch 22/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6706 - val_loss: 0.6662
# Epoch 23/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6703 - val_loss: 0.6656
# Epoch 24/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6695 - val_loss: 0.6650
# Epoch 25/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6692 - val_loss: 0.6644
# Epoch 26/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6683 - val_loss: 0.6639
# Epoch 27/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6681 - val_loss: 0.6634
# Epoch 28/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6673 - val_loss: 0.6630
# Epoch 29/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6668 - val_loss: 0.6625
# Epoch 30/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6664 - val_loss: 0.6621
# Epoch 31/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6663 - val_loss: 0.6617
# Epoch 32/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6656 - val_loss: 0.6613
# Epoch 33/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6654 - val_loss: 0.6609
# Epoch 34/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6649 - val_loss: 0.6605
# Epoch 35/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6642 - val_loss: 0.6602
# Epoch 36/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6644 - val_loss: 0.6598
# Epoch 37/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6639 - val_loss: 0.6595
# Epoch 38/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6631 - val_loss: 0.6591
# Epoch 39/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6634 - val_loss: 0.6588
# Epoch 40/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6628 - val_loss: 0.6585
# Epoch 41/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6625 - val_loss: 0.6581
# Epoch 42/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6622 - val_loss: 0.6578
# Epoch 43/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6621 - val_loss: 0.6575
# Epoch 44/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6616 - val_loss: 0.6572
# Epoch 45/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6615 - val_loss: 0.6569
# Epoch 46/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6612 - val_loss: 0.6567
# Epoch 47/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6606 - val_loss: 0.6564
# Epoch 48/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6602 - val_loss: 0.6561
# Epoch 49/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6605 - val_loss: 0.6559
# Epoch 50/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6599 - val_loss: 0.6557
# Epoch 51/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6597 - val_loss: 0.6555
# Epoch 52/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6594 - val_loss: 0.6553
# Epoch 53/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6596 - val_loss: 0.6552
# Epoch 54/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6596 - val_loss: 0.6550
# Epoch 55/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6588 - val_loss: 0.6548
# Epoch 56/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6588 - val_loss: 0.6547
# Epoch 57/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6587 - val_loss: 0.6546
# Epoch 58/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6586 - val_loss: 0.6545
# Epoch 59/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6582 - val_loss: 0.6543
# Epoch 60/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6587 - val_loss: 0.6542
# Epoch 61/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6585 - val_loss: 0.6542
# Epoch 62/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6584 - val_loss: 0.6541
# Epoch 63/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6583 - val_loss: 0.6540
# Epoch 64/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6581 - val_loss: 0.6539
# Epoch 65/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6583 - val_loss: 0.6539
# Epoch 66/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6582 - val_loss: 0.6538
# Epoch 67/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6579 - val_loss: 0.6538
# Epoch 68/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6577 - val_loss: 0.6537
# Epoch 69/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6580 - val_loss: 0.6537
# Epoch 70/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6579 - val_loss: 0.6536
# Epoch 71/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6581 - val_loss: 0.6536
# Epoch 72/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6574 - val_loss: 0.6536
# Epoch 73/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6576 - val_loss: 0.6536
# Epoch 74/100
# 39/39 [==============================] - 1s 15ms/step - loss: 0.6576 - val_loss: 0.6535
# Epoch 75/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6574 - val_loss: 0.6535
# Epoch 76/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6577 - val_loss: 0.6535
# Epoch 77/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6577 - val_loss: 0.6535
# Epoch 78/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6577 - val_loss: 0.6535
# Epoch 79/100
# 39/39 [==============================] - 1s 18ms/step - loss: 0.6577 - val_loss: 0.6534
# Epoch 80/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6575 - val_loss: 0.6534
# Epoch 81/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6573 - val_loss: 0.6534
# Epoch 82/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6574 - val_loss: 0.6534
# Epoch 83/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6577 - val_loss: 0.6534
# Epoch 84/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6576 - val_loss: 0.6533
# Epoch 85/100
# 39/39 [==============================] - 0s 13ms/step - loss: 0.6574 - val_loss: 0.6533
# Epoch 86/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6570 - val_loss: 0.6533
# Epoch 87/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6575 - val_loss: 0.6533
# Epoch 88/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6572 - val_loss: 0.6533
# Epoch 89/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6573 - val_loss: 0.6533
# Epoch 90/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6576 - val_loss: 0.6532
# Epoch 91/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6573 - val_loss: 0.6532
# Epoch 92/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6574 - val_loss: 0.6532
# Epoch 93/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6571 - val_loss: 0.6532
# Epoch 94/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6571 - val_loss: 0.6532
# Epoch 95/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6570 - val_loss: 0.6531
# Epoch 96/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6572 - val_loss: 0.6531
# Epoch 97/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6572 - val_loss: 0.6531
# Epoch 98/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.6575 - val_loss: 0.6531
# Epoch 99/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6568 - val_loss: 0.6531
# Epoch 100/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6573 - val_loss: 0.6530

# %%
plot_history(history)
plot_examples(x_test_deep, decoded_stocks)
